# %%
from mynotebooks import *
# %matplotlib inline  
from ExpRobotSetup import ExpSetupDualCartPole

exp = ExpSetupDualCartPole()
# Out:
# -------------------------------------------------
# Created Exp Dual Cart Pole Setup  simple Debug:  False

# %%
#exp.resetPosition()
for i in range(2): Box2DWorld.step()

fig, ax = VectorFigUtils.makeFigure(axes=[-5,5,-1.5,5.5])
Box2DWorld.plotWorld(ax)
VectorFigUtils.decorate("x","y",mainfont=16)
ax.set_aspect('equal')
plt.show()
fig.savefig('imgs/setup.png', dpi=300, format='png')

# %%
exp.setMotorSpeed(0,2)
for i in range(100): Box2DWorld.step()
    
fig, ax = VectorFigUtils.makeFigure(axes=[-5,5,-1.5,5.5])
Box2DWorld.plotWorld(ax)
plt.show()
